# %% [markdown]
# # First Exploration of Flats Fits Files of Monocam
# ================================================================
#
# - date of creation : Monday 30th 2016
# - Update : Friday 3rd 2016
# - author : Sylvie Dagoret-Campagne
# - affiliation : LAL/IN2P3/CNRS

# %% [markdown]
# Study images for LSST calibration group

# %%
import numpy as np

# Set up matplotlib and use a nicer set of plot parameters
#config InlineBackend.rc = {}
#config Backend.rc = {}
import matplotlib
matplotlib.rc_file("../templates/matplotlibrc")  # default config obtained from astropy examples
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/dagoret-campagnesylvie/anaconda/envs/pyastrophys/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
from astropy.utils.data import download_file

# %%
from astropy.io import fits

# %%
import os

# %% [markdown]
# ## 1) to define the input file for the images

# %%
path='/Users/dagoret-campagnesylvie/iraf/MonoCamMay2016/20160509'

# %%
filename='skyflats_01.fits'

# %%
flatnumber=1

# %%
flatnumberstr= '{0:02d}'.format(flatnumber)  # python >= 2.6
flatnumberstr
# Out:
# '01'

# %%
image_file=os.path.join(path,filename)

# %% [markdown]
# ## 2) to inspect the header of the file

# %%
header=fits.getheader(image_file) # to retreive the header of the file
#fits.getheader(image_file)
#print header
#header

# %% [markdown]
# In this call, you see the number of images in the file:
# - 16 images of size 544 x 2048 pixels
# corresponding of :
# - 8 columns of 544 pixels : 8 x 544 = 4352 pixels
# - 2 raws of 2048 pixels : 2 x 2048 = 4096 pixels
#
# There is an excess of 4352-4096= 256 pixels along the columns.
# It is possible there is 32 overscan slots.

# %%
hdu_list = fits.open(image_file)
hdu_list.info()
# Out:
# Filename: /Users/dagoret-campagnesylvie/iraf/MonoCamMay2016/20160509/skyflats_01.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     554   ()
# 1                ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 2                ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 3                ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 4                ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 5                ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 6                ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 7                ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 8                ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 9                ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 10               ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 11               ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 12               ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 13               ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 14               ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 15               ImageHDU        33   (544, 2048)   int16 (rescales to uint16)
# 16               ImageHDU        33   (544, 2048)   int16 (rescales to uint16)

# %% [markdown]
# ## 3) A view of the header

# %%
header=hdu_list[0].header
header
# Out:
# SIMPLE  =                    T / conform to FITS standard
# BITPIX  =                   16 / unsigned short data
# NAXIS   =                    0 / number of axes
# EXTEND  =                    T / this is FITS with extensions
# HISTORY Created with RTS2 version 0.9.4 build on May  6 2016 18:01:35.
# CTIME   =           1462847518 / exposure start (seconds since 1.1.1970)
# USEC    =               607136 / exposure start micro seconds
# JD      =     2457518.60553241 / exposure JD
# DATE-OBS= '2016-05-10T02:31:58.607' / start of exposure
# EXPOSURE=                   2. / exposure length in seconds
# EXPTIME =                   2. / exposure length in seconds
# INSTRUME= '113-03  '           / name of the data acqusition instrument
# TELESCOP= 'USNO 1.3m'          / name of the data acqusition telescope
# ORIGIN  = 'BNL     '           / organisation responsible for data
# NUMBER  =                    1 /  exposure number
# SCRIPREP=                    0 / script loop count
# SCRIPT  = 'E 2     '           / script used to take this images
# SCR_COMM= '        '           / comment recorded for this script
# COMM_NUM=                    0 / comment order within current script
# CCD_TYPE= '        '           / camera type
# CCD_SER = '        '           / camera serial number
# BINNING = '1x1     '           / [pixelX x pixelY] chip binning
# BINX    =                    1 / [pixels] binning along X axis
# BINY    =                    1 / [pixels] binning along X axis
# SHUTTER =                    0 / shutter state (0 - opened, 1 - closed)
# HIERARCH DATA_CHANNELS =    16 / total number of data channels
# CHAN    =                   16 / channels on/off
# CHAN1   =                    T
# CHAN2   =                    T
# CHAN3   =                    T
# CHAN4   =                    T
# CHAN5   =                    T
# CHAN6   =                    T
# CHAN7   =                    T
# CHAN8   =                    T
# CHAN9   =                    T
# CHAN10  =                    T
# CHAN11  =                    T
# CHAN12  =                    T
# CHAN13  =                    T
# CHAN14  =                    T
# CHAN15  =                    T
# CHAN16  =                    T
# CONFIG  = '/home/ccdtest/reflex/Timing/e2v250/545kHz_20160504.rcf' / path to the
# RAW_MODE=                    F / RAW readout mode
# HIERARCH baud_rate = '9600    ' / CL baud rate
# HIERARCH int.error_code =    0 / holds the error code fomr the most recent error
# HIERARCH int.error_source =  0 / holds an integer identifying the source of the
# HIERARCH int.error_line =    0 / holds the line number in the interface CPUs
# HIERARCH int.status_index = 144973 / a counter that increments every time the in
# HIERARCH int.power =         3 / current CCD power state
# HIERARCH int.backplane_type = 268566784 / board type field for the backplane boa
# HIERARCH int.interface_type = 537067776 / board type field for the interface boa
# HIERARCH int.powerA_type = 805634304 / PowerA board type
# HIERARCH int.powerB_type = 1074004224 / PowerB board type
# HIERARCH int.daughter1_type = 1359085824 / Daughter 1 board type
# HIERARCH int.daughter2_type = 0 / Daughter 2 board type
# HIERARCH int.daughter3_type = 1879245056 / Daughter 3 board type
# HIERARCH int.daughter4_type = 1879245056 / Daughter 4 board type
# HIERARCH int.daughter5_type = 1610875136 / Daughter 5 board type
# HIERARCH int.daughter6_type = 1359085824 / Daughter 6 board type
# HIERARCH int.daughter7_type = 0 / Daughter 7 board type
# HIERARCH int.daughter8_type = 0 / Daughter 8 board type
# HIERARCH int.backplane_ROM = 342747023 / Backplane ROM ID
# HIERARCH int.interface_ROM = 354346805 / Backplane ROM ID
# HIERARCH int.powerA_ROM = 357033833 / PowerA ROM ID
# HIERARCH int.powerB_ROM = 356892114 / PowerB ROM ID
# HIERARCH int.daughter1_ROM = 356215559 / Daughter 1 ROM ID
# HIERARCH int.daughter2_ROM = 0 / Daughter 2 ROM ID
# HIERARCH int.daughter3_ROM = 356202439 / Daughter 3 ROM ID
# HIERARCH int.daughter4_ROM = 356217931 / Daughter 4 ROM ID
# HIERARCH int.daughter5_ROM = 357076386 / Daughter 5 ROM ID
# HIERARCH int.daughter6_ROM = 342740541 / Daughter 6 ROM ID
# HIERARCH int.daughter7_ROM = 0 / Daughter 7 ROM ID
# HIERARCH int.daughter8_ROM = 0 / Daughter 8 ROM ID
# HIERARCH int.backplane_build = 354 / Backplane firmware build number
# HIERARCH int.interface_build = 455 / Backplane firmware build number
# HIERARCH int.powerA_build = 422 / PowerA firmware build number
# HIERARCH int.powerB_build = 437 / PowerB firmware build number
# HIERARCH int.daughter1_build = 320 / Daughter 1 firmware build number
# HIERARCH int.daughter2_build = 0 / Daughter 2 firmware build number
# HIERARCH int.daughter3_build = 449 / Daughter 3 firmware build number
# HIERARCH int.daughter4_build = 449 / Daughter 4 firmware build number
# HIERARCH int.daughter5_build = 443 / Daughter 5 firmware build number
# HIERARCH int.daughter6_build = 320 / Daughter 6 firmware build number
# HIERARCH int.daughter7_build = 0 / Daughter 7 firmware build number
# HIERARCH int.daughter8_build = 0 / Daughter 8 firmware build number
# HIERARCH int.backplane_flags = 0 / Backplane feature flags
# HIERARCH int.interface_flags = 0 / Backplane feature flags
# HIERARCH int.powerA_flags =  0 / PowerA feature flags
# HIERARCH int.powerB_flags =  0 / PowerB feature flags
# HIERARCH int.daughter1_flags = 0 / Daughter 1 feature flags
# HIERARCH int.daughter2_flags = 0 / Daughter 2 feature flags
# HIERARCH int.daughter3_flags = 0 / Daughter 3 feature flags
# HIERARCH int.daughter4_flags = 0 / Daughter 4 feature flags
# HIERARCH int.daughter5_flags = 0 / Daughter 5 feature flags
# HIERARCH int.daughter6_flags = 0 / Daughter 6 feature flags
# HIERARCH int.daughter7_flags = 0 / Daughter 7 feature flags
# HIERARCH int.daughter8_flags = 0 / Daughter 8 feature flags
# HIERARCH sys.timing_lines = 130 / Number of lines of timining data
# HIERARCH back.temperature = 19.625 / [C] backplane module temperature
# HIERARCH back.status =      65 / backplane status
# MCLK    =            100000000 / [Hz} master clock frequency (60 MHz - 100 MHz)
# HIERARCH daughter_enable =  33 / bit-field specifying which AD daughter modules
# HIERARCH pair_count =        0 / number of pairs of AD daughter modules the back
# HIERARCH pair_0chA =         1 / daughter module to read on Channel A of Pair 0
# HIERARCH pair_0chB =         0 / daughter module to read on Channel B of Pair 0
# HIERARCH pair_1chA =         0 / daughter module to read on Channel A of Pair 1
# HIERARCH pair_1chB =         0 / daughter module to read on Channel B of Pair 1
# HIERARCH pair_2chA =        32 / daughter module to read on Channel A of Pair 2
# HIERARCH pair_2chB =         0 / daughter module to read on Channel B of Pair 2
# HIERARCH pair_3chA =         0 / daughter module to read on Channel A of Pair 3
# HIERARCH pair_3chB =         0 / daughter module to read on Channel B of Pair 3
# HIERARCH clif.temperature = 18.312 / [C] camera link module temperature
# HIERARCH clif.tap_count =    7 / number of pairs per active pixel clock
# HIERARCH clif.loop_count = 543 / number active pixel clocks per line
# HIERARCH clif.tapA0_start = 255 / channel A tap 0 start address in line buffer
# HIERARCH clif.tapA1_start = 255 / channel A tap 1 start address in line buffer
# HIERARCH clif.tapA2_start = 1088 / channel A tap 2 start address in line buffer
# HIERARCH clif.tapA3_start = 3264 / channel A tap 3 start address in line buffer
# HIERARCH clif.tapA4_start =  0 / channel A tap 4 start address in line buffer
# HIERARCH clif.tapA5_start = 2176 / channel A tap 5 start address in line buffer
# HIERARCH clif.tapA6_start = 1632 / channel A tap 6 start address in line buffer
# HIERARCH clif.tapA7_start = 3808 / channel A tap 7 start address in line buffer
# HIERARCH clif.tapA8_start = 544 / channel A tap 8 start address in line buffer
# HIERARCH clif.tapA9_start = 2720 / channel A tap 9 start address in line buffer
# HIERARCH clif.tapA10_start = 0 / channel A tap 10 start address in line buffer
# HIERARCH clif.tapA11_start = 0 / channel A tap 11 start address in line buffer
# HIERARCH clif.tapA12_start = 0 / channel A tap 12 start address in line buffer
# HIERARCH clif.tapA13_start = 0 / channel A tap 13 start address in line buffer
# HIERARCH clif.tapA14_start = 0 / channel A tap 14 start address in line buffer
# HIERARCH clif.tapA15_start = 0 / channel A tap 15 start address in line buffer
# HIERARCH clif.tapA16_start = 0 / channel A tap 16 start address in line buffer
# HIERARCH clif.tapA17_start = 0 / channel A tap 17 start address in line buffer
# HIERARCH clif.tapA18_start = 0 / channel A tap 18 start address in line buffer
# HIERARCH clif.tapA19_start = 0 / channel A tap 19 start address in line buffer
# HIERARCH clif.tapA20_start = 0 / channel A tap 20 start address in line buffer
# HIERARCH clif.tapA21_start = 0 / channel A tap 21 start address in line buffer
# HIERARCH clif.tapA22_start = 0 / channel A tap 22 start address in line buffer
# HIERARCH clif.tapA23_start = 0 / channel A tap 23 start address in line buffer
# HIERARCH clif.tapA24_start = 0 / channel A tap 24 start address in line buffer
# HIERARCH clif.tapA25_start = 0 / channel A tap 25 start address in line buffer
# HIERARCH clif.tapA26_start = 0 / channel A tap 26 start address in line buffer
# HIERARCH clif.tapA27_start = 0 / channel A tap 27 start address in line buffer
# HIERARCH clif.tapA28_start = 0 / channel A tap 28 start address in line buffer
# HIERARCH clif.tapA29_start = 0 / channel A tap 29 start address in line buffer
# HIERARCH clif.tapA30_start = 0 / channel A tap 30 start address in line buffer
# HIERARCH clif.tapA31_start = 0 / channel A tap 31 start address in line buffer
# HIERARCH clif.tapB0_start =  0 / channel B tap 0 start address in line buffer
# HIERARCH clif.tapB1_start =  0 / channel B tap 1 start address in line buffer
# HIERARCH clif.tapB2_start = 5440 / channel B tap 2 start address in line buffer
# HIERARCH clif.tapB3_start = 7616 / channel B tap 3 start address in line buffer
# HIERARCH clif.tapB4_start = 4352 / channel B tap 4 start address in line buffer
# HIERARCH clif.tapB5_start = 6528 / channel B tap 5 start address in line buffer
# HIERARCH clif.tapB6_start = 5984 / channel B tap 6 start address in line buffer
# HIERARCH clif.tapB7_start = 8160 / channel B tap 7 start address in line buffer
# HIERARCH clif.tapB8_start = 4896 / channel B tap 8 start address in line buffer
# HIERARCH clif.tapB9_start = 7072 / channel B tap 9 start address in line buffer
# HIERARCH clif.tapB10_start = 0 / channel B tap 10 start address in line buffer
# HIERARCH clif.tapB11_start = 0 / channel B tap 11 start address in line buffer
# HIERARCH clif.tapB12_start = 0 / channel B tap 12 start address in line buffer
# HIERARCH clif.tapB13_start = 0 / channel B tap 13 start address in line buffer
# HIERARCH clif.tapB14_start = 0 / channel B tap 14 start address in line buffer
# HIERARCH clif.tapB15_start = 0 / channel B tap 15 start address in line buffer
# HIERARCH clif.tapB16_start = 0 / channel B tap 16 start address in line buffer
# HIERARCH clif.tapB17_start = 0 / channel B tap 17 start address in line buffer
# HIERARCH clif.tapB18_start = 0 / channel B tap 18 start address in line buffer
# HIERARCH clif.tapB19_start = 0 / channel B tap 19 start address in line buffer
# HIERARCH clif.tapB20_start = 0 / channel B tap 20 start address in line buffer
# HIERARCH clif.tapB21_start = 0 / channel B tap 21 start address in line buffer
# HIERARCH clif.tapB22_start = 0 / channel B tap 22 start address in line buffer
# HIERARCH clif.tapB23_start = 0 / channel B tap 23 start address in line buffer
# HIERARCH clif.tapB24_start = 0 / channel B tap 24 start address in line buffer
# HIERARCH clif.tapB25_start = 0 / channel B tap 25 start address in line buffer
# HIERARCH clif.tapB26_start = 0 / channel B tap 26 start address in line buffer
# HIERARCH clif.tapB27_start = 0 / channel B tap 27 start address in line buffer
# HIERARCH clif.tapB28_start = 0 / channel B tap 28 start address in line buffer
# HIERARCH clif.tapB29_start = 0 / channel B tap 29 start address in line buffer
# HIERARCH clif.tapB30_start = 0 / channel B tap 30 start address in line buffer
# HIERARCH clif.tapB31_start = 0 / channel B tap 31 start address in line buffer
# HIERARCH clif.tapA0_delta =  0 / channel A tap 0 delta address in line buffer
# HIERARCH clif.tapA1_delta =  0 / channel A tap 1 delta address in line buffer
# HIERARCH clif.tapA2_delta =  1 / channel A tap 2 delta address in line buffer
# HIERARCH clif.tapA3_delta =  1 / channel A tap 3 delta address in line buffer
# HIERARCH clif.tapA4_delta =  1 / channel A tap 4 delta address in line buffer
# HIERARCH clif.tapA5_delta =  1 / channel A tap 5 delta address in line buffer
# HIERARCH clif.tapA6_delta =  1 / channel A tap 6 delta address in line buffer
# HIERARCH clif.tapA7_delta =  1 / channel A tap 7 delta address in line buffer
# HIERARCH clif.tapA8_delta =  1 / channel A tap 8 delta address in line buffer
# HIERARCH clif.tapA9_delta =  1 / channel A tap 9 delta address in line buffer
# HIERARCH clif.tapA10_delta = 0 / channel A tap 10 delta address in line buffer
# HIERARCH clif.tapA11_delta = 0 / channel A tap 11 delta address in line buffer
# HIERARCH clif.tapA12_delta = 0 / channel A tap 12 delta address in line buffer
# HIERARCH clif.tapA13_delta = 0 / channel A tap 13 delta address in line buffer
# HIERARCH clif.tapA14_delta = 0 / channel A tap 14 delta address in line buffer
# HIERARCH clif.tapA15_delta = 0 / channel A tap 15 delta address in line buffer
# HIERARCH clif.tapA16_delta = 0 / channel A tap 16 delta address in line buffer
# HIERARCH clif.tapA17_delta = 0 / channel A tap 17 delta address in line buffer
# HIERARCH clif.tapA18_delta = 0 / channel A tap 18 delta address in line buffer
# HIERARCH clif.tapA19_delta = 0 / channel A tap 19 delta address in line buffer
# HIERARCH clif.tapA20_delta = 0 / channel A tap 20 delta address in line buffer
# HIERARCH clif.tapA21_delta = 0 / channel A tap 21 delta address in line buffer
# HIERARCH clif.tapA22_delta = 0 / channel A tap 22 delta address in line buffer
# HIERARCH clif.tapA23_delta = 0 / channel A tap 23 delta address in line buffer
# HIERARCH clif.tapA24_delta = 0 / channel A tap 24 delta address in line buffer
# HIERARCH clif.tapA25_delta = 0 / channel A tap 25 delta address in line buffer
# HIERARCH clif.tapA26_delta = 0 / channel A tap 26 delta address in line buffer
# HIERARCH clif.tapA27_delta = 0 / channel A tap 27 delta address in line buffer
# HIERARCH clif.tapA28_delta = 0 / channel A tap 28 delta address in line buffer
# HIERARCH clif.tapA29_delta = 0 / channel A tap 29 delta address in line buffer
# HIERARCH clif.tapA30_delta = 0 / channel A tap 30 delta address in line buffer
# HIERARCH clif.tapA31_delta = 0 / channel A tap 31 delta address in line buffer
# HIERARCH clif.tapB0_delta =  0 / channel B tap 0 delta address in line buffer
# HIERARCH clif.tapB1_delta =  0 / channel B tap 1 delta address in line buffer
# HIERARCH clif.tapB2_delta =  1 / channel B tap 2 delta address in line buffer
# HIERARCH clif.tapB3_delta =  1 / channel B tap 3 delta address in line buffer
# HIERARCH clif.tapB4_delta =  1 / channel B tap 4 delta address in line buffer
# HIERARCH clif.tapB5_delta =  1 / channel B tap 5 delta address in line buffer
# HIERARCH clif.tapB6_delta =  1 / channel B tap 6 delta address in line buffer
# HIERARCH clif.tapB7_delta =  1 / channel B tap 7 delta address in line buffer
# HIERARCH clif.tapB8_delta =  1 / channel B tap 8 delta address in line buffer
# HIERARCH clif.tapB9_delta =  1 / channel B tap 9 delta address in line buffer
# HIERARCH clif.tapB10_delta = 0 / channel B tap 10 delta address in line buffer
# HIERARCH clif.tapB11_delta = 0 / channel B tap 11 delta address in line buffer
# HIERARCH clif.tapB12_delta = 0 / channel B tap 12 delta address in line buffer
# HIERARCH clif.tapB13_delta = 0 / channel B tap 13 delta address in line buffer
# HIERARCH clif.tapB14_delta = 0 / channel B tap 14 delta address in line buffer
# HIERARCH clif.tapB15_delta = 0 / channel B tap 15 delta address in line buffer
# HIERARCH clif.tapB16_delta = 0 / channel B tap 16 delta address in line buffer
# HIERARCH clif.tapB17_delta = 0 / channel B tap 17 delta address in line buffer
# HIERARCH clif.tapB18_delta = 0 / channel B tap 18 delta address in line buffer
# HIERARCH clif.tapB19_delta = 0 / channel B tap 19 delta address in line buffer
# HIERARCH clif.tapB20_delta = 0 / channel B tap 20 delta address in line buffer
# HIERARCH clif.tapB21_delta = 0 / channel B tap 21 delta address in line buffer
# HIERARCH clif.tapB22_delta = 0 / channel B tap 22 delta address in line buffer
# HIERARCH clif.tapB23_delta = 0 / channel B tap 23 delta address in line buffer
# HIERARCH clif.tapB24_delta = 0 / channel B tap 24 delta address in line buffer
# HIERARCH clif.tapB25_delta = 0 / channel B tap 25 delta address in line buffer
# HIERARCH clif.tapB26_delta = 0 / channel B tap 26 delta address in line buffer
# HIERARCH clif.tapB27_delta = 0 / channel B tap 27 delta address in line buffer
# HIERARCH clif.tapB28_delta = 0 / channel B tap 28 delta address in line buffer
# HIERARCH clif.tapB29_delta = 0 / channel B tap 29 delta address in line buffer
# HIERARCH clif.tapB30_delta = 0 / channel B tap 30 delta address in line buffer
# HIERARCH clif.tapB31_delta = 0 / channel B tap 31 delta address in line buffer
# HIERARCH clif.line_length =  0 / line length in camera clock cycles
# HIERARCH clif.precount =     0 / dummy camera link clock cycles before LVAL high
# HIERARCH clif.postcount = 8703 / dummy camera link clock cycles after LVAL low
# HIERARCH clif.line_count =   7 / number of camera link lines
# HIERARCH clif.idle_count =   7 / number of idle camera link lines between frames
# HIERARCH clif.link_mode = 2047 / camera link mode
# HIERARCH pwrA.temperature = 22.188 / [C] power module temperature
# HIERARCH pwrA.p5VD_V =   4.953 / [V] +5V digital supply voltage reading
# HIERARCH pwrA.p5VD_A =    4045 / [mA] +5V digital supply current reading
# HIERARCH pwrA.p5VA_V =   4.949 / [V] +5V analog supply voltage reading
# HIERARCH pwrA.p5VA_A =     809 / [mA] +5V analog supply current reading
# HIERARCH pwrA.m5VA_V =  -4.939 / [V] -5V analog supply voltage reading
# HIERARCH pwrA.m5VA_A =    -908 / [mA] -5V analog supply current reading
# HIERARCH pwrB.temperature = 15.625 / [C] power module temperature
# HIERARCH pwrB.p30VA_V = 35.969 / [V] +30V analog supply voltage reading
# HIERARCH pwrB.p30VA_A =   -169 / [mA] +30V analog supply current reading
# HIERARCH pwrB.p15VA_V = 14.981 / [V] +51V analog supply voltage reading
# HIERARCH pwrB.p15VA_A =   -420 / [mA] +15V analog supply current reading
# HIERARCH pwrB.m15VA_V = -15.034 / [V] -15V analog supply voltage reading
# HIERARCH pwrB.m15VA_A =    264 / [mA] -15V analog supply current reading
# HIERARCH pwrB.TEC_mon = -273.15 / [C] monitored value of TEC setpoint
# HIERARCH pwrB.TEC_actual = -273.15 / [C] current TEC temperature
# HIERARCH pwrB.TEC_set = -273.15 / [C] TEC setpoint (zero to disable)
# HIERARCH AD_1.temperature = 20.438 / [C] module temperature
# HIERARCH AD_1.status =      65 / module status
# HIERARCH AD_1.clamp_low =   0. / [V] clamp voltage for negative side pf differen
# HIERARCH AD_1.clamp_high = 1.2 / [V] clamp voltage for positive side pf differen
# HIERARCH AD_1.raw_mode =     0 / CDS/raw mode
# HIERARCH AD_1.raw_channel =  0 / AD channel to stream in raw mode, 0-7
# HIERARCH AD_1.cds_gain =    1. / fixed point gain to apply in CDS mode (0x000100
# HIERARCH AD_1.cds_offset = 1000. / fixed point offset to apply in CDS mode
# HIERARCH AD_1.hdr_mode =     0 / Normal/HDR (32 bit) sample mode
# HIERARCH AD_1.cds_reset_start = 80 / starting sample to use for CDS reset level
# HIERARCH AD_1.cds_reset_stop = 110 / last sample to use for CDS reset level afte
# HIERARCH AD_1.cds_video_start = 140 / starting sample to use for CDS video level
# HIERARCH AD_1.cda_video_stop = 170 / last sample to use for CDS video level afte
# HIERARCH BIAS_1.temperature = 16.125 / [C] module temperature
# HIERARCH BIAS_1.status =   833 / module status
# HIERARCH BIAS_1.OG_Vmeas =  4. / [V] Low-voltage bias #1 voltage
# HIERARCH BIAS_1.L2_Vmeas =  0. / [V] Low-voltage bias #2 voltage
# HIERARCH BIAS_1.L3_Vmeas = -0.001 / [V] Low-voltage bias #3 voltage
# HIERARCH BIAS_1.L4_Vmeas =  0. / [V] Low-voltage bias #4 voltage
# HIERARCH BIAS_1.L5_Vmeas = -1.212 / [V] Low-voltage bias #5 voltage
# HIERARCH BIAS_1.L6_Vmeas = -0.001 / [V] Low-voltage bias #6 voltage
# HIERARCH BIAS_1.L7_Vmeas =  0. / [V] Low-voltage bias #7 voltage
# HIERARCH BIAS_1.L8_Vmeas = -0.001 / [V] Low-voltage bias #8 voltage
# HIERARCH BIAS_1.OD1_Vmeas = 29.5 / [V] High-voltage bias #1 voltage
# HIERARCH BIAS_1.OD2_Vmeas = 29.5 / [V] High-voltage bias #2 voltage
# HIERARCH BIAS_1.OD3_Vmeas = 29.501 / [V] High-voltage bias #3 voltage
# HIERARCH BIAS_1.OD4_Vmeas = 29.5 / [V] High-voltage bias #4 voltage
# HIERARCH BIAS_1.OD5_Vmeas = 29.5 / [V] High-voltage bias #5 voltage
# HIERARCH BIAS_1.OD6_Vmeas = 29.5 / [V] High-voltage bias #6 voltage
# HIERARCH BIAS_1.OD7_Vmeas = 29.5 / [V] High-voltage bias #7 voltage
# HIERARCH BIAS_1.OD8_Vmeas = 29.501 / [V] High-voltage bias #8 voltage
# HIERARCH BIAS_1.OG_Cmeas = 8247 / [uA] Low voltage bias #1 current
# HIERARCH BIAS_1.L2_Cmeas =   0 / [uA] Low voltage bias #2 current
# HIERARCH BIAS_1.L3_Cmeas =   1 / [uA] Low voltage bias #3 current
# HIERARCH BIAS_1.L4_Cmeas =   1 / [uA] Low voltage bias #4 current
# HIERARCH BIAS_1.L5_Cmeas = -33 / [uA] Low voltage bias #5 current
# HIERARCH BIAS_1.L6_Cmeas =   0 / [uA] Low voltage bias #6 current
# HIERARCH BIAS_1.L7_Cmeas =   1 / [uA] Low voltage bias #7 current
# HIERARCH BIAS_1.L8_Cmeas =   1 / [uA] Low voltage bias #8 current
# HIERARCH BIAS_1.OD1_Cmeas = 10786 / [uA] High-voltage bias #1 current
# HIERARCH BIAS_1.OD2_Cmeas = 10809 / [uA] High-voltage bias #2 current
# HIERARCH BIAS_1.OD3_Cmeas = 10801 / [uA] High-voltage bias #3 current
# HIERARCH BIAS_1.OD4_Cmeas = 10773 / [uA] High-voltage bias #4 current
# HIERARCH BIAS_1.OD5_Cmeas = 10737 / [uA] High-voltage bias #5 current
# HIERARCH BIAS_1.OD6_Cmeas = 10765 / [uA] High-voltage bias #6 current
# HIERARCH BIAS_1.OD7_Cmeas = 10712 / [uA] High-voltage bias #7 current
# HIERARCH BIAS_1.OD8_Cmeas = 10810 / [uA] High-voltage bias #8 current
# HIERARCH BIAS_1.bias_enable = 65281 / bit field identifing which biash channels
# HIERARCH BIAS_1.OG_V =      4. / [V] DC bias level for LV 1
# HIERARCH BIAS_1.L2_V =      0. / [V] DC bias level for LV 2
# HIERARCH BIAS_1.L3_V =      0. / [V] DC bias level for LV 3
# HIERARCH BIAS_1.L4_V =      0. / [V] DC bias level for LV 4
# HIERARCH BIAS_1.L5_V =      0. / [V] DC bias level for LV 5
# HIERARCH BIAS_1.L6_V =      0. / [V] DC bias level for LV 6
# HIERARCH BIAS_1.L7_V =      0. / [V] DC bias level for LV 7
# HIERARCH BIAS_1.L8_V =      0. / [V] DC bias level for LV 8
# HIERARCH BIAS_1.OD1_V =   29.5 / [V] DC bias level for HV 1
# HIERARCH BIAS_1.OD2_V =   29.5 / [V] DC bias level for HV 2
# HIERARCH BIAS_1.OD3_V =   29.5 / [V] DC bias level for HV 3
# HIERARCH BIAS_1.OD4_V =   29.5 / [V] DC bias level for HV 4
# HIERARCH BIAS_1.OD5_V =   29.5 / [V] DC bias level for HV 5
# HIERARCH BIAS_1.OD6_V =   29.5 / [V] DC bias level for HV 6
# HIERARCH BIAS_1.OD7_V =   29.5 / [V] DC bias level for HV 7
# HIERARCH BIAS_1.OD8_V =   29.5 / [V] DC bias level for HV 8
# HIERARCH BIAS_1.OG_C =   10000 / [uA] current limit for LV 1
# HIERARCH BIAS_1.L2_C =       0 / [uA] current limit for LV 2
# HIERARCH BIAS_1.L3_C =       0 / [uA] current limit for LV 3
# HIERARCH BIAS_1.L4_C =       0 / [uA] current limit for LV 4
# HIERARCH BIAS_1.L5_C =       0 / [uA] current limit for LV 5
# HIERARCH BIAS_1.L6_C =       0 / [uA] current limit for LV 6
# HIERARCH BIAS_1.L7_C =       0 / [uA] current limit for LV 7
# HIERARCH BIAS_1.L8_C =       0 / [uA] current limit for LV 8
# HIERARCH BIAS_1.OD1_C =  50000 / [uA] current limit for HV 1
# HIERARCH BIAS_1.OD2_C =  50000 / [uA] current limit for HV 2
# HIERARCH BIAS_1.OD3_C =  50000 / [uA] current limit for HV 3
# HIERARCH BIAS_1.OD4_C =  50000 / [uA] current limit for HV 4
# HIERARCH BIAS_1.OD5_C =  50000 / [uA] current limit for HV 5
# HIERARCH BIAS_1.OD6_C =  50000 / [uA] current limit for HV 6
# HIERARCH BIAS_1.OD7_C =  50000 / [uA] current limit for HV 7
# HIERARCH BIAS_1.OD8_C =  50000 / [uA] current limit for HV 8
# HIERARCH BIAS_2.temperature = 15.125 / [C] module temperature
# HIERARCH BIAS_2.status =   833 / module status
# HIERARCH BIAS_2.L1_Vmeas =  0. / [V] Low-voltage bias #1 voltage
# HIERARCH BIAS_2.L2_Vmeas =  0. / [V] Low-voltage bias #2 voltage
# HIERARCH BIAS_2.L3_Vmeas = -0.001 / [V] Low-voltage bias #3 voltage
# HIERARCH BIAS_2.L4_Vmeas =  0. / [V] Low-voltage bias #4 voltage
# HIERARCH BIAS_2.L5_Vmeas = -0.001 / [V] Low-voltage bias #5 voltage
# HIERARCH BIAS_2.L6_Vmeas =  0. / [V] Low-voltage bias #6 voltage
# HIERARCH BIAS_2.L7_Vmeas = -0.001 / [V] Low-voltage bias #7 voltage
# HIERARCH BIAS_2.L8_Vmeas =  0. / [V] Low-voltage bias #8 voltage
# HIERARCH BIAS_2.RD_Vmeas = 17.999 / [V] High-voltage bias #1 voltage
# HIERARCH BIAS_2.DD_Vmeas = 25.997 / [V] High-voltage bias #2 voltage
# HIERARCH BIAS_2.H3_Vmeas = 0.127 / [V] High-voltage bias #3 voltage
# HIERARCH BIAS_2.H4_Vmeas = 0.24 / [V] High-voltage bias #4 voltage
# HIERARCH BIAS_2.H5_Vmeas = 0.033 / [V] High-voltage bias #5 voltage
# HIERARCH BIAS_2.H6_Vmeas =  0. / [V] High-voltage bias #6 voltage
# HIERARCH BIAS_2.H7_Vmeas = -0.001 / [V] High-voltage bias #7 voltage
# HIERARCH BIAS_2.H8_Vmeas = -0.002 / [V] High-voltage bias #8 voltage
# HIERARCH BIAS_2.L1_Cmeas =   0 / [uA] Low voltage bias #1 current
# HIERARCH BIAS_2.L2_Cmeas =   1 / [uA] Low voltage bias #2 current
# HIERARCH BIAS_2.L3_Cmeas =   2 / [uA] Low voltage bias #3 current
# HIERARCH BIAS_2.L4_Cmeas =   1 / [uA] Low voltage bias #4 current
# HIERARCH BIAS_2.L5_Cmeas =   2 / [uA] Low voltage bias #5 current
# HIERARCH BIAS_2.L6_Cmeas =   1 / [uA] Low voltage bias #6 current
# HIERARCH BIAS_2.L7_Cmeas =   1 / [uA] Low voltage bias #7 current
# HIERARCH BIAS_2.L8_Cmeas =   1 / [uA] Low voltage bias #8 current
# HIERARCH BIAS_2.RD_Cmeas = 690 / [uA] High-voltage bias #1 current
# HIERARCH BIAS_2.DD_Cmeas = 997 / [uA] High-voltage bias #2 current
# HIERARCH BIAS_2.H3_Cmeas =  -1 / [uA] High-voltage bias #3 current
# HIERARCH BIAS_2.H4_Cmeas =   5 / [uA] High-voltage bias #4 current
# HIERARCH BIAS_2.H5_Cmeas =   0 / [uA] High-voltage bias #5 current
# HIERARCH BIAS_2.H6_Cmeas =   0 / [uA] High-voltage bias #6 current
# HIERARCH BIAS_2.H7_Cmeas =  -2 / [uA] High-voltage bias #7 current
# HIERARCH BIAS_2.H8_Cmeas =  -1 / [uA] High-voltage bias #8 current
# HIERARCH BIAS_2.bias_enable = 768 / bit field identifing which biash channels to
# HIERARCH BIAS_2.L1_V =      0. / [V] DC bias level for LV 1
# HIERARCH BIAS_2.L2_V =      0. / [V] DC bias level for LV 2
# HIERARCH BIAS_2.L3_V =      0. / [V] DC bias level for LV 3
# HIERARCH BIAS_2.L4_V =      0. / [V] DC bias level for LV 4
# HIERARCH BIAS_2.L5_V =      0. / [V] DC bias level for LV 5
# HIERARCH BIAS_2.L6_V =      0. / [V] DC bias level for LV 6
# HIERARCH BIAS_2.L7_V =      0. / [V] DC bias level for LV 7
# HIERARCH BIAS_2.L8_V =      0. / [V] DC bias level for LV 8
# HIERARCH BIAS_2.RD_V =     18. / [V] DC bias level for HV 1
# HIERARCH BIAS_2.DD_V =     26. / [V] DC bias level for HV 2
# HIERARCH BIAS_2.H3_V =      0. / [V] DC bias level for HV 3
# HIERARCH BIAS_2.H4_V =      0. / [V] DC bias level for HV 4
# HIERARCH BIAS_2.H5_V =      0. / [V] DC bias level for HV 5
# HIERARCH BIAS_2.H6_V =      0. / [V] DC bias level for HV 6
# HIERARCH BIAS_2.H7_V =      0. / [V] DC bias level for HV 7
# HIERARCH BIAS_2.H8_V =      0. / [V] DC bias level for HV 8
# HIERARCH BIAS_2.L1_C =       0 / [uA] current limit for LV 1
# HIERARCH BIAS_2.L2_C =       0 / [uA] current limit for LV 2
# HIERARCH BIAS_2.L3_C =       0 / [uA] current limit for LV 3
# HIERARCH BIAS_2.L4_C =       0 / [uA] current limit for LV 4
# HIERARCH BIAS_2.L5_C =       0 / [uA] current limit for LV 5
# HIERARCH BIAS_2.L6_C =       0 / [uA] current limit for LV 6
# HIERARCH BIAS_2.L7_C =       0 / [uA] current limit for LV 7
# HIERARCH BIAS_2.L8_C =       0 / [uA] current limit for LV 8
# HIERARCH BIAS_2.RD_C =   50000 / [uA] current limit for HV 1
# HIERARCH BIAS_2.DD_C =   50000 / [uA] current limit for HV 2
# HIERARCH BIAS_2.H3_C =       0 / [uA] current limit for HV 3
# HIERARCH BIAS_2.H4_C =       0 / [uA] current limit for HV 4
# HIERARCH BIAS_2.H5_C =       0 / [uA] current limit for HV 5
# HIERARCH BIAS_2.H6_C =       0 / [uA] current limit for HV 6
# HIERARCH BIAS_2.H7_C =       0 / [uA] current limit for HV 7
# HIERARCH BIAS_2.H8_C =       0 / [uA] current limit for HV 8
# HIERARCH DRV_1.temperature = 16.438 / [C] module temperature
# HIERARCH DRV_1.status =    841 / module status
# HIERARCH DRV_1.driver_enable = 511 / bit-field indetifing which driver channels
# HIERARCH DRV_1.P1_low =     0. / [V] low level clock voltage for channel ch1
# HIERARCH DRV_1.P1_high =    9. / [V] high level clock voltage for channel ch1
# HIERARCH DRV_1.P1_slew =   10. / [V] clock slew rate for channel ch1
# HIERARCH DRV_1.P2_low =     0. / [V] low level clock voltage for channel ch2
# HIERARCH DRV_1.P2_high =    9. / [V] high level clock voltage for channel ch2
# HIERARCH DRV_1.P2_slew =   10. / [V] clock slew rate for channel ch2
# HIERARCH DRV_1.P3_low =     0. / [V] low level clock voltage for channel ch3
# HIERARCH DRV_1.P3_high =    9. / [V] high level clock voltage for channel ch3
# HIERARCH DRV_1.P3_slew =   10. / [V] clock slew rate for channel ch3
# HIERARCH DRV_1.P4_low =     0. / [V] low level clock voltage for channel ch4
# HIERARCH DRV_1.P4_high =    9. / [V] high level clock voltage for channel ch4
# HIERARCH DRV_1.P4_slew =   10. / [V] clock slew rate for channel ch4
# HIERARCH DRV_1.S1_low =    0.5 / [V] low level clock voltage for channel ch5
# HIERARCH DRV_1.S1_high =   9.5 / [V] high level clock voltage for channel ch5
# HIERARCH DRV_1.S1_slew =  500. / [V] clock slew rate for channel ch5
# HIERARCH DRV_1.S2_low =    0.5 / [V] low level clock voltage for channel ch6
# HIERARCH DRV_1.S2_high =   9.5 / [V] high level clock voltage for channel ch6
# HIERARCH DRV_1.S2_slew =  100. / [V] clock slew rate for channel ch6
# HIERARCH DRV_1.S3_low =    0.5 / [V] low level clock voltage for channel ch7
# HIERARCH DRV_1.S3_high =   9.5 / [V] high level clock voltage for channel ch7
# HIERARCH DRV_1.S3_slew =  500. / [V] clock slew rate for channel ch7
# HIERARCH DRV_1.RG_low =     0. / [V] low level clock voltage for channel ch8
# HIERARCH DRV_1.RG_high =   12. / [V] high level clock voltage for channel ch8
# HIERARCH DRV_1.RG_slew =  500. / [V] clock slew rate for channel ch8
# HIERARCH DRV_1.CLBAR_low = 0.7 / [V] low level clock voltage for channel ch9
# HIERARCH DRV_1.CLBAR_high = 2.2 / [V] high level clock voltage for channel ch9
# HIERARCH DRV_1.CLBAR_slew = 10. / [V] clock slew rate for channel ch9
# HIERARCH DRV_1.notused_low = 0. / [V] low level clock voltage for channel ch10
# HIERARCH DRV_1.notused_high = 0. / [V] high level clock voltage for channel ch10
# HIERARCH DRV_1.notused_slew = 0. / [V] clock slew rate for channel ch10
# HIERARCH DRV_1.ch11_low =   0. / [V] low level clock voltage for channel ch11
# HIERARCH DRV_1.ch11_high =  0. / [V] high level clock voltage for channel ch11
# HIERARCH DRV_1.ch11_slew =  0. / [V] clock slew rate for channel ch11
# HIERARCH DRV_1.ch12_low =   0. / [V] low level clock voltage for channel ch12
# HIERARCH DRV_1.ch12_high =  0. / [V] high level clock voltage for channel ch12
# HIERARCH DRV_1.ch12_slew =  0. / [V] clock slew rate for channel ch12
# HIERARCH AD_2.temperature = 19.875 / [C] module temperature
# HIERARCH AD_2.status =      65 / module status
# HIERARCH AD_2.clamp_low =   0. / [V] clamp voltage for negative side pf differen
# HIERARCH AD_2.clamp_high = 1.2 / [V] clamp voltage for positive side pf differen
# HIERARCH AD_2.raw_mode =     0 / CDS/raw mode
# HIERARCH AD_2.raw_channel =  0 / AD channel to stream in raw mode, 0-7
# HIERARCH AD_2.cds_gain =    1. / fixed point gain to apply in CDS mode (0x000100
# HIERARCH AD_2.cds_offset = 1000. / fixed point offset to apply in CDS mode
# HIERARCH AD_2.hdr_mode =     0 / Normal/HDR (32 bit) sample mode
# HIERARCH AD_2.cds_reset_start = 80 / starting sample to use for CDS reset level
# HIERARCH AD_2.cds_reset_stop = 110 / last sample to use for CDS reset level afte
# HIERARCH AD_2.cds_video_start = 140 / starting sample to use for CDS video level
# HIERARCH AD_2.cda_video_stop = 170 / last sample to use for CDS video level afte
# HIERARCH sys.LCLK =          0 / 20-bit value for timing core parameter 1
# HIERARCH sys.NCLEAR =     2002 / 20-bit value for timing core parameter 2
# HIERARCH sys.NPUMP =         0 / 20-bit value for timing core parameter 3
# HIERARCH sys.PDEPTH =        1 / 20-bit value for timing core parameter 4
# HIERARCH sys.ROWSKIP =       0 / 20-bit value for timing core parameter 5
# HIERARCH sys.ROWREAD =    2048 / 20-bit value for timing core parameter 6
# HIERARCH sys.ROWOVER =       0 / 20-bit value for timing core parameter 7
# HIERARCH sys.PIXSKIP =       0 / 20-bit value for timing core parameter 8
# HIERARCH sys.PIXREAD =     544 / 20-bit value for timing core parameter 9
# HIERARCH sys.PIXOVER =       0 / 20-bit value for timing core parameter 10
# HIERARCH sys.EXPO =          1 / 20-bit value for timing core parameter 11
# HIERARCH sys.EXPTIME =    2000 / 20-bit value for timing core parameter 12
# HIERARCH sys.WAITIME =     500 / 20-bit value for timing core parameter 13
# HIERARCH sys.NEXPO =         1 / 20-bit value for timing core parameter 14
# HIERARCH sys.LIGHT =         1 / 20-bit value for timing core parameter 15
# HIERARCH sys.TPA =        2000 / 20-bit value for timing core parameter 16
# HIERARCH sys.TPB =        2000 / 20-bit value for timing core parameter 17
# HIERARCH sys.TSR1 =          0 / 20-bit value for timing core parameter 18
# HIERARCH sys.TSR2 =         10 / 20-bit value for timing core parameter 19
# HIERARCH sys.TSR3 =         10 / 20-bit value for timing core parameter 20
# HIERARCH sys.TSR4 =         10 / 20-bit value for timing core parameter 21
# HIERARCH sys.TSR5 =          5 / 20-bit value for timing core parameter 22
# HIERARCH sys.TSR6 =         80 / 20-bit value for timing core parameter 23
# HIERARCH sys.TSR7 =          7 / 20-bit value for timing core parameter 24
# HIERARCH sys.TSR8 =         52 / 20-bit value for timing core parameter 25
# HIERARCH sys.TSF =          60 / 20-bit value for timing core parameter 26
# HIERARCH sys.TWAIT =       100 / 20-bit value for timing core parameter 27
# HIERARCH R0.MODE = 'default '  / mode name
# HIERARCH AMP2.IDN = 'NDCI-0.00003E-03' / identification string
# HIERARCH AMP2.ON =           T / If voltage source is switched on
# HIERARCH AMP2.VOLTAGE =   -50. / [V] voltage level
# HIERARCH AMP2.ZERO_CHECK = 'off     ' / Zero check on/off
# HIERARCH CRYO.IDN = 'Cryocon,Model 34,201986,4.16' / identification string
# HIERARCH CRYO.A.TEMP = -120.001038 / cryocon temperature from channel A
# HIERARCH CRYO.A.MINIMUM = -132.661819 / minimum temperature on channel A
# HIERARCH CRYO.A.MAXIMUM = 9.467896 / maximum temperature on channel A
# HIERARCH CRYO.A.VARIANCE = 2491.579102 / temperature variance of channel A
# HIERARCH CRYO.A.SLOPE = 4.1E-05 / slope of channel A
# HIERARCH CRYO.A.OFFSET = -87.668915 / temp offset of channel A
# HIERARCH CRYO.B.TEMP = -8.473663 / cryocon temperature from channel B
# HIERARCH CRYO.B.MINIMUM = -101.43158 / minimum temperature on channel B
# HIERARCH CRYO.B.MAXIMUM = 8.342529 / maximum temperature on channel B
# HIERARCH CRYO.B.VARIANCE = 61.773296 / temperature variance of channel B
# HIERARCH CRYO.B.SLOPE = 5.6E-05 / slope of channel B
# HIERARCH CRYO.B.OFFSET = -9.272003 / temp offset of channel B
# HIERARCH CRYO.C.TEMP = -235.392288 / cryocon temperature from channel C
# HIERARCH CRYO.C.MINIMUM = -237.970718 / minimum temperature on channel C
# HIERARCH CRYO.C.MAXIMUM = -218.633682 / maximum temperature on channel C
# HIERARCH CRYO.C.VARIANCE = 42.19265 / temperature variance of channel C
# HIERARCH CRYO.C.SLOPE = 9.0E-06 / slope of channel C
# HIERARCH CRYO.C.OFFSET = -231.004257 / temp offset of channel C
# HIERARCH CRYO.D.TEMP =      0. / cryocon temperature from channel D
# HIERARCH CRYO.D.MINIMUM =   0. / minimum temperature on channel D
# HIERARCH CRYO.D.MAXIMUM =   0. / maximum temperature on channel D
# HIERARCH CRYO.D.VARIANCE =  0. / temperature variance of channel D
# HIERARCH CRYO.D.SLOPE =     0. / slope of channel D
# HIERARCH CRYO.D.OFFSET =    0. / temp offset of channel D
# HIERARCH CRYO.1.SOURCE = 'CHA     ' / Control loop source input
# HIERARCH CRYO.1.SETPT =  -120. / Control loop set point
# HIERARCH CRYO.1.TYPE = 'PID     ' / Control loop control type
# HIERARCH CRYO.1.RANGE = '25W     ' / Control loop output range
# HIERARCH CRYO.1.RAMP =       F / Control loop ramp status
# HIERARCH CRYO.1.RATE =     1.5 / [K/min] Control loop ramp rate
# HIERARCH CRYO.1.PGAIN =    20. / Control loop proportional gain term
# HIERARCH CRYO.1.IGAIN =    80. / Control loop integral gain term
# HIERARCH CRYO.1.DGAIN =    20. / Control loop derivative gain term
# HIERARCH CRYO.1.HTRREAD =   0. / Control loop output current
# HIERARCH CRYO.1.PMANUAL =  50. / Control loop manual power output setting
# HIERARCH CRYO.2.SOURCE = 'CHA     ' / Control loop source input
# HIERARCH CRYO.2.SETPT =   -59. / Control loop set point
# HIERARCH CRYO.2.TYPE = 'PID     ' / Control loop control type
# HIERARCH CRYO.2.RANGE = 'HTR     ' / Control loop output range
# HIERARCH CRYO.2.RAMP =       F / Control loop ramp status
# HIERARCH CRYO.2.RATE =     0.1 / [K/min] Control loop ramp rate
# HIERARCH CRYO.2.PGAIN =    0.1 / Control loop proportional gain term
# HIERARCH CRYO.2.IGAIN =    0.5 / Control loop integral gain term
# HIERARCH CRYO.2.DGAIN =     0. / Control loop derivative gain term
# HIERARCH CRYO.2.HTRREAD =   0. / Control loop output current
# HIERARCH CRYO.2.PMANUAL =   1. / Control loop manual power output setting
# HIERARCH CRYO.STATTIME = 358500.99612 / time for which statistic was collected
# HIERARCH CRYO.AMBIENT =    37. / cryocon ambient temperature
# HIERARCH CRYO.HTRREAD =     0. / Heater read back current
# HIERARCH CRYO.HTRHST =     27. / Heater heat sink temperature
# HIERARCH CRYO.HEATER =       T / Heater enabled/disabled
# HIERARCH AMP2.CURRENT = -40000. / [pA] measured current (in picoAmps)
# CAM_FILT=                    0 / filter used for image
# FILTER  = 'UNK     '           / camera filter as string
# DATE    = '2016-05-10T02:32:11.319' / creation date

# %% [markdown]
# #### 3.1 )notes on somes of the cards
#
# ##### which instrument and who
#
# - HISTORY Created with RTS2 version 0.9.4 build on May  6 2016 18:01:35. : the controler for the CCD
# - INSTRUME= '113-03  '           / name of the data acqusition instrument  : The EVL chip
# - TELESCOP= 'USNO 1.3m'          / name of the data acqusition telescope   : 1.3 m telescope
# - ORIGIN  = 'BNL     '           / organisation responsible for data    : the team
#
# ##### about the dates
# - DATE    = '2016-05-10T01:07:55.503' / creation date  : Tango militay time zone (pacific west ) UTC -7
# - CTIME   =           1462842471 / exposure start (seconds since 1.1.1970)
# - USEC    =               926250 / exposure start micro seconds
# - JD      =     2457518.54711806 / exposure JD
# - DATE-OBS= '2016-05-10T01:07:51.926' / start of exposure  : it should be in UTC

# %% [markdown]
# #### 3.2) extract the number of amplifiers

# %%
number_of_channels=header['CHAN']
print 'number_of_channels=', number_of_channels
# Out:
# number_of_channels= 16

# %% [markdown]
# #### 3.3) extract the time

# %%
import pandas as pd
from datetime import datetime, timedelta
from pytz import timezone
import pytz

# %%
timestr=header['DATE']
print timestr  # I don't know what to to from the .XXX after the second number
tzstr=timestr.split('.')[0]  # cut away the dot
print tzstr
datetime.strptime(tzstr, "%Y-%m-%dT%H:%M:%S")
# Out:
# 2016-05-10T02:32:11.319
# 2016-05-10T02:32:11
# datetime.datetime(2016, 5, 10, 2, 32, 11)

# %% [markdown]
# ## 4) read one amplifier

# %%
numchan=1

# %%
image_data = hdu_list[numchan].data

# %%
image_data.shape
# Out:
# (2048, 544)

# %%
# better not to close the file here
#hdu_list.close()

# %% [markdown]
# #### another way to read the image
# But it is not interesting because it does not select the channel number

# %%
image_data = fits.getdata(image_file)
image_data_flat=image_data.flatten()
print(type(image_data))
print(image_data.shape)
themin=image_data.min()
themax=image_data.max()
print(themin,themax)
# Out:
# <type 'numpy.ndarray'>
# (2048, 544)
# (2624, 43602)

# %% [markdown]
# ### 4.1) View the channel 1

# %%
title='Flat for channel {} for flat file{} '.format(numchan,flatnumber)
fig = plt.figure()
ax = fig.add_subplot(111)
plt.hist(image_data_flat,bins=1000);
ax.set_title(title)
ax.set_xlabel('ADU')
ax.grid(True)
plt.yscale('log')
plt.show()

# %%
NX=2
NY=1
fig, axarr = plt.subplots(NY,NX,figsize=(10,10))
im1=axarr[0].imshow(image_data, cmap='gray',vmin=17000,vmax=21000)
axarr[0].set_title('ADU from 17000 to 21000')
plt.colorbar(im1, ax = axarr[0])

im2=axarr[1].imshow(image_data, cmap='gray',vmin=9000,vmax=10000)
axarr[1].set_title('ADU from 9000 to 10000')
plt.colorbar(im2, ax = axarr[1])

fig.subplots_adjust(right=1)

title='Bias for channel {} for flat file {} '.format(numchan,flatnumber)

plt.suptitle(title,size=16)
plt.show()

# %% [markdown]
# ## Shows the corresponding histogram of flats values

# %%
NX=2
NY=1
image_data_flat=image_data.flatten()

fig, axarr = plt.subplots(NY,NX,figsize=(10,5))

axarr[0].hist(image_data_flat,bins=1000);
axarr[0].set_title('ADU from 18000 to 19500')
axarr[0].set_xlim(18000,19500)
axarr[0].set_xlabel('ADU')


axarr[1].hist(image_data_flat,bins=1000);
axarr[1].set_title('ADU from 9000 to 10000')
axarr[1].set_xlim(9000,10000)
axarr[1].set_ylim(0,1000)
axarr[1].set_xlabel('ADU')

title='Flat for channel {} for flat file {} '.format(numchan,flatnumber)

plt.suptitle(title,size=16)
plt.show()

# %% [markdown]
# ## Low and high values histograms

# %%
aducut1=9000
aducut2=9800

aducut3=18000
aducut4=19200

highvalue = image_data_flat[np.where( np.logical_and(image_data_flat> aducut3, image_data_flat< aducut4)) ]
lowvalue = image_data_flat[np.where( np.logical_and(image_data_flat> aducut1,image_data_flat< aducut2)) ]

hvmean=highvalue.mean()
hvrms=highvalue.std()
hvtitle='mean={:5.1f} std={:4.2f}'.format(hvmean,hvrms)

lvmean=lowvalue.mean()
lvrms=lowvalue.std()
lvtitle='mean={:5.1f} std={:4.2f}'.format(lvmean,lvrms)

NX=2
NY=1
image_data_flat=image_data.flatten()

fig, axarr = plt.subplots(NY,NX,figsize=(10,5))

axarr[0].hist(highvalue,bins=100,facecolor='blue', alpha=0.75,label=hvtitle);
#axarr[0].set_title(hvtitle)
axarr[0].set_xlabel('ADU')
axarr[0].legend(loc='best')

axarr[1].hist(lowvalue,bins=100,facecolor='blue', alpha=0.75,label=lvtitle);
#axarr[1].set_title(lvtitle)
axarr[1].set_xlabel('ADU')
axarr[1].legend(loc='best')

title='Flat for channel {} for flat file {} '.format(numchan,flatnumber)

plt.suptitle(title,size=14)
plt.show()

# %% [markdown]
# ## Try to find where are the Bias and Trim sections

# %%
aducut1=9000
aducut2=9800

aducut3=18000
aducut4=19200

aducut5=5000

row_hv,col_hv = np.where( np.logical_and(image_data> aducut3, image_data< aducut4)) 
row_lv,col_lv = np.where( np.logical_and(image_data> aducut1,image_data< aducut2)) 
row_vvl,col_vvl = np.where(image_data< aducut5)

# %%
print 'row_hv = ',row_hv
print 'col_hv = ',col_hv
print 'row_lv = ',row_lv
print 'col_lv = ',col_lv
print 'row_vvl = ',row_vvl
print 'col_vvl = ',col_vvl
# Out:
# row_hv =  [   0    0    0 ..., 1999 2000 2000]
# col_hv =  [ 59  64  65 ..., 517 517 518]
# row_lv =  [   5    6    7 ..., 1995 1996 1997]
# col_lv =  [521 521 521 ..., 521 521 521]
# row_vvl =  [   0    0    0 ..., 2047 2047 2047]
# col_vvl =  [522 523 524 ..., 541 542 543]

# %%
nrow,ncol =image_data.shape
print nrow
print ncol

firstcol = image_data[:,0]
othercol = image_data[:,1:ncol]

lowvalue = firstcol.flatten()
highvalue = othercol.flatten()

hvmean=highvalue.mean()
hvrms=highvalue.std()
hvtitle='mean={:5.1f} std={:4.2f}'.format(hvmean,hvrms)

lvmean=lowvalue.mean()
lvrms=lowvalue.std()
lvtitle='mean={:5.1f} std={:4.2f}'.format(lvmean,lvrms)

NX=2
NY=1
image_data_flat=image_data.flatten()

fig, axarr = plt.subplots(NY,NX,figsize=(10,5))

axarr[0].hist(highvalue,bins=100,facecolor='blue', alpha=0.75,label=hvtitle);
#axarr[0].set_title(hvtitle)
axarr[0].set_xlabel('ADU')
axarr[0].legend(loc='best')

axarr[1].hist(lowvalue,bins=100,facecolor='blue', alpha=0.75,label=lvtitle);
#axarr[1].set_title(lvtitle)
axarr[1].set_xlabel('ADU')
axarr[1].legend(loc='best')

title='Flat for channel {} for Flat file {} '.format(numchan,flatnumber)

plt.suptitle(title,size=14)
plt.show()
# Out:
# 2048
# 544

# %% [markdown]
# ### localize where are too low values
#
# - low values pixels where ADU < 5000

# %%
ix,iy=np.where(image_data<2700)
print('rows number where there is the anomaly',ix)
print ('columns where there is the anomaly',iy)
print ('the values of the bias',image_data[ix,iy])
# Out:
# ('row number where there is the anomaly', array([   1,    2,    3, ..., 2045, 2046, 2047]))
# ('column where there is the anomaly', array([0, 0, 0, ..., 0, 0, 0]))
# ('the values of the bias', array([2629, 2633, 2630, ..., 2630, 2630, 2630], dtype=uint16))

# %%
def ShowImagesSet(path,filename):
    '''
    Shows the whole set of CCD images
     - inputs argument:
       path : path of the fits file
       filename of the fits file
     - output the images of the whole CCD   
    '''
    image_file=os.path.join(path,filename) # make the full filename    
    hdu_list = fits.open(image_file)       # open the file
    #hdu_list.info()	 # to know the composition of the files (header+images)		
    header=hdu_list[0].header           # retrieve the header
    number_of_channels=header['CHAN']   # number of channels in the CCD
    
    NX=8 # number of images along the horizontal axis
    NY=2 # number of images along the vertical axis
    f, axarr = plt.subplots(NY,NX,sharex='col', sharey='row',figsize=(15,15)) # figure organisation
    #f, axarr = plt.subplots(NX,NY,sharex=True, sharey=True,figsize=(20,20))
    f.subplots_adjust(hspace=0.05,wspace=0.05)

    for index in range(0,number_of_channels,1):  
        ix=index%8
        iy=index/8
        image_data = hdu_list[index+1].data
        im=axarr[iy,ix].imshow(image_data, cmap='rainbow')  # plot the image
        #plt.colorbar(im, orientation='horizontal')
        plottitle='channel {}'.format(index+1)
        axarr[iy,ix].set_title(plottitle)
    hdu_list.close()
    title='Flat for flat file {} '.format(flatnumber)
    plt.suptitle(title,size=16)

# %%
ShowImagesSet(path,image_file)

# %%
def ShowHistoSet(path,filename):
    '''
    Shows the whole set of CCD histograms
     - inputs argument:
       path : path of the fits file
       filename of the fits file
     - output the images of the whole CCD   
    '''
    image_file=os.path.join(path,filename) # make the full filename    
    hdu_list = fits.open(image_file)       # open the file
    #hdu_list.info()	 # to know the composition of the files (header+images)		
    header=hdu_list[0].header           # retrieve the header
    number_of_channels=header['CHAN']   # number of channels in the CCD
    
    NX=4 # number of images along the horizontal axis
    NY=4 # number of images along the vertical axis
    f, axarr = plt.subplots(NY,NX,figsize=(20,20)) # figure organisation
    #f, axarr = plt.subplots(NX,NY,sharex=True, sharey=True,figsize=(20,20))
    f.subplots_adjust(hspace=0.5,wspace=0.5)

    for index in range(0,number_of_channels,1):  
        ix=index%4
        iy=index/4
        image_data = hdu_list[index+1].data
        data=image_data.flatten()
        axarr[iy,ix].hist(data,bins=500,facecolor='blue', alpha=0.75,log=True)  # plot the image
        plottitle='channel {}'.format(index+1)
        axarr[iy,ix].set_title(plottitle)
        axarr[iy,ix].set_xlabel('ADU')
        axarr[iy,ix].grid(True)
        #axarr[iy,ix].set_yscale('log')
        
    hdu_list.close()
    plt.yscale('log')
    title='Flat for flat file {} '.format(flatnumber)
    plt.suptitle(title,size=16)

# %%
ShowHistoSet(path,image_file)

# %% [markdown]
# ## Show the horizontal and vertical profiles of the flats

# %%
def ShowHistoSetAxis(path,filename,ax=0):
    '''
    Shows the whole set of CCD histograms
     - inputs argument:
       path : path of the fits file
       filename of the fits file
     - output the images of the whole CCD   
    '''
    image_file=os.path.join(path,filename) # make the full filename    
    hdu_list = fits.open(image_file)       # open the file
    #hdu_list.info()	 # to know the composition of the files (header+images)		
    header=hdu_list[0].header           # retrieve the header
    number_of_channels=header['CHAN']   # number of channels in the CCD
    
    NX=4 # number of images along the horizontal axis
    NY=4 # number of images along the vertical axis
    f, axarr = plt.subplots(NY,NX,figsize=(20,20)) # figure organisation
    #f, axarr = plt.subplots(NX,NY,sharex=True, sharey=True,figsize=(20,20))
    f.subplots_adjust(hspace=0.5,wspace=0.5)

    for index in range(0,number_of_channels,1):  
        ix=index%4
        iy=index/4
        image_data = hdu_list[index+1].data
        data=np.mean(image_data,axis=ax)
        axarr[iy,ix].plot(data)  # plot the image
        plottitle='channel {}'.format(index+1)
        axarr[iy,ix].set_title(plottitle)
        axarr[iy,ix].set_xlabel('ADU')
        axarr[iy,ix].grid(True)
        #axarr[iy,ix].set_yscale('log')
        
    hdu_list.close()
    #plt.yscale('log')
    title='Flat for flat file {} axis {} '.format(flatnumber,ax)
    plt.suptitle(title,size=16)

# %%
ShowHistoSetAxis(path,image_file)

# %%
ShowHistoSetAxis(path,image_file,ax=1)

# %%
def ShowHistoSumAxis(path,filename,ax=0):
    '''
    Shows the whole set of CCD histograms
     - inputs argument:
       path : path of the fits file
       filename of the fits file
     - output the images of the whole CCD   
    '''
    image_file=os.path.join(path,filename) # make the full filename    
    hdu_list = fits.open(image_file)       # open the file
    #hdu_list.info()	 # to know the composition of the files (header+images)		
    header=hdu_list[0].header           # retrieve the header
    number_of_channels=header['CHAN']   # number of channels in the CCD
    
    NX=1 # number of images along the horizontal axis
    NY=1 # number of images along the vertical axis
    f, axarr = plt.subplots(NY,NX,figsize=(20,6)) # figure organisation

    for index in range(0,number_of_channels,1):  
        
        image_data = hdu_list[index+1].data
        data=np.mean(image_data,axis=ax)
        min=data.min()
        max=data.max()
        plabel='channel {}'.format(index+1)
        plt.plot(np.arange(data.shape[0]),data,label=plabel)  # plot the image
    
    if ax == 0:
        plt.xticks(np.arange(0, data.shape[0]+1, 10.))
    else:
        plt.xticks(np.arange(0, data.shape[0]+1, 50.))
    hdu_list.close()
    plt.legend(loc='best')
    title='Flat for flat file {} axis {} '.format(flatnumber,ax)
    plt.suptitle(title,size=16)

# %%
ShowHistoSumAxis(path,image_file)

# %%
ShowHistoSumAxis(path,image_file,ax=1)

# %% [markdown]
# ### Conclusion on Trimsec and biasec
#
# I have compared this matplotlib and ds9.
#
# - here we consider averages of values along vertical and horizontal axis
# - In DS9 we can see the transition between a trim and a bias sectionat a given position (X,Y)
#
# The image is vertically flipped between matplotlib and DS9 (Y flip)
#
# I suggest the following  definition of Trimsec and biassec in numpy definitions
#
# - Trimsec: [0:2000,10:520]
# - Biassec: [0:2000,521:544]
