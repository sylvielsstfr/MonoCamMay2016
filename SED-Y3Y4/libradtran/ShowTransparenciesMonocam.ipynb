# %% [markdown]
# # Transparencies for Monocam
#
# - author Sylvie Dagoret-Campagne
# - creation date Sunday Jyly 3rd 2016

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
# %matplotlib inline

# %%
currentpath=os.getcwd()
outpath='./monocam_2016-05-09-y3/afglus'
root_filename='UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_'
#pre_filename='pwv05_'
pre_filename='pwv10_'
ext_filename='.out'
numstart=1
numstop=10

# %%
#currentpath=os.getcwd()
#outpath='./monocam_2016-05-09-y4/afglus'
#root_filename='UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_'
#pre_filename='pwv05_'
#pre_filename='pwv10_'
#ext_filename='.out'
#numstart=1
#numstop=8

# %%
filelist = []
NBFILES=numstop-numstart+1
for index in range(numstart,numstop+1):
    if index != 102:
        filename=root_filename+pre_filename+str(index)+ext_filename
        fullfilename=os.path.join(outpath,filename)
        filelist.append(fullfilename)

# %%
filelist
# Out:
# ['./monocam_2016-05-09-y3/afglus/UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_pwv10_1.out',
#  './monocam_2016-05-09-y3/afglus/UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_pwv10_2.out',
#  './monocam_2016-05-09-y3/afglus/UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_pwv10_3.out',
#  './monocam_2016-05-09-y3/afglus/UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_pwv10_4.out',
#  './monocam_2016-05-09-y3/afglus/UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_pwv10_5.out',
#  './monocam_2016-05-09-y3/afglus/UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_pwv10_6.out',
#  './monocam_2016-05-09-y3/afglus/UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_pwv10_7.out',
#  './monocam_2016-05-09-y3/afglus/UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_pwv10_8.out',
#  './monocam_2016-05-09-y3/afglus/UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_pwv10_9.out',
#  './monocam_2016-05-09-y3/afglus/UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_pwv10_10.out']

# %%
fig1 = plt.figure(figsize=(20,15))
for index,file in enumerate(filelist):       
    array=np.loadtxt(file)
    x=array[:,0]
    y=array[:,1]
    plt.plot(x,y,'-')   
plt.xlim([0, 1200.])
plt.tick_params(axis='y', which='minor')
plt.grid(True,which='both')
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlabel('$\lambda$ (nm)',fontsize=20)
plt.ylabel('air attenuation',fontsize=20)
plt.title('Atmospheric attenuation at NOFS',fontsize=30)
plt.legend(loc='best')
