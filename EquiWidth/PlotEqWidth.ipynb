# %%
import numpy as np

# %config InlineBackend.rc = {}
import matplotlib
matplotlib.rc_file("../templates/matplotlibrc")

import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
# Out:
# /Users/dagoret-campagnesylvie/anaconda/envs/pyastrophys/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
from astropy.io import fits

# %%
from IPython.display import Image

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
class PDF(object):
  def __init__(self, pdf, size=(200,200)):
    self.pdf = pdf
    self.size = size

  def _repr_html_(self):
    return '<iframe src={0} width={1[0]} height={1[1]}></iframe>'.format(self.pdf, self.size)

  def _repr_latex_(self):
    return r'\includegraphics[width=1.0\textwidth]{{{0}}}'.format(self.pdf)

# %% [markdown]
# # O2 absorption line

# %%
#Image(filename='Equivalent_Width_plot_O2.pdf')
PDF('Equivalent_Width_plot_O2.pdf',size=(600,500))
# Out:
# \includegraphics[width=1.0\textwidth]{Equivalent_Width_plot_O2.pdf}

# %% [markdown]
#     AirMass : [1.1070173712070741, 1.7710645458576959, 1.4353960968637178, 1.2256076238203211]
#     data O2 : [1.4368520791415296, 1.6248595458109285, 1.5533474638378753, 1.5278171326625194]
#     error data O2 : [0.030612215520111681, 0.028028537750969685, 0.02039842190470165, 0.02430873507831563]
#     pred O2 :  [2.6914602158721053, 3.3790377804954916, 3.0626187869218646, 2.8339278751825034]
#     error pred O2 : [0.033197288271909584, 0.034702095234333888, 0.03386344678347164, 0.033419132990500422]

# %%
AirMass=np.array( [ 1.7710645458576959, 1.4353960968637178, 1.2256076238203211,1.1070173712070741])

# %%
dataO2=np.array([ 1.6248595458109285, 1.5533474638378753, 1.5278171326625194,1.4368520791415296])

# %%
errdataO2=np.array( [ 0.028028537750969685, 0.02039842190470165, 0.02430873507831563,0.030612215520111681])

# %%
predO2=np.array([ 3.3790377804954916, 3.0626187869218646, 2.8339278751825034,2.6914602158721053])

# %%
errpredO2=np.array([ 0.034702095234333888, 0.03386344678347164, 0.033419132990500422,0.033197288271909584])

# %%
plt.figure(figsize=(10,6))
plt.plot(AirMass,dataO2,'r--')
plt.errorbar(AirMass,dataO2,yerr=errdataO2 ,
                                 fmt='s',
                                 markersize = 3,
                                 color = 'r',
                                zorder = 300,
                                antialiased = True,linewidth=2,label='data')
plt.plot(AirMass,predO2,'b--')
plt.errorbar(AirMass,predO2,yerr=errpredO2 ,
                            fmt = 'o',
                            markersize = 3,
                            color = 'b',
                            zorder = 300,
                            antialiased = True,linewidth=2,label='libradtran')
plt.xlabel('airmass')
plt.ylabel('equivalent width in nm')
plt.ylim(0.,5.)
plt.title('equivalent width for atmospheric O$_2$ absorption line (759 nm)')
plt.legend(loc='upper left')

# %% [markdown]
# # H-beta line

# %%
PDF('Equivalent_Width_plot_Hbeta.pdf',size=(600,500))
# Out:
# \includegraphics[width=1.0\textwidth]{Equivalent_Width_plot_Hbeta.pdf}

# %% [markdown]
#     AirMass : [1.1070173712070741, 1.7710645458576959, 1.4353960968637178, 1.2256076238203211]
#     data Hbeta : [2.0271607200645878, 1.8627796890909143, 1.9921972503805361, 1.9456643286832969]
#     error data Hbeta : [0.012949786485659299, 0.023749438301007269, 0.010841391072622133, 0.013152549869047771]
#     pred Hbeta :  [1.9095603312275922, 1.90019361225057, 1.9048680093050767, 1.9078521323875961]
#     error pred Hbeta : [0.018873823165005542, 0.019205688610065049, 0.019031344005033785, 0.018929189235314503]

# %%
AirMass=np.array([ 1.7710645458576959, 1.4353960968637178, 1.2256076238203211,1.1070173712070741])
dataHbeta=np.array([1.8627796890909143, 1.9921972503805361, 1.9456643286832969,2.0271607200645878 ])
errdataHbeta=np.array([ 0.023749438301007269, 0.010841391072622133, 0.013152549869047771,0.012949786485659299])
predHbeta=np.array([ 1.90019361225057, 1.9048680093050767, 1.9078521323875961,1.9095603312275922])
errpredHbeta=np.array([ 0.019205688610065049, 0.019031344005033785, 0.018929189235314503,0.018873823165005542])

# %%
plt.figure(figsize=(10,6))
plt.plot(AirMass,dataHbeta,'r--')
plt.errorbar(AirMass,dataHbeta,yerr=errdataHbeta ,
                                 fmt='s',
                                 markersize = 3,
                                 color = 'r',
                                zorder = 300,
                                antialiased = True,linewidth=2,label='data')
plt.plot(AirMass,predHbeta,'b--')
plt.errorbar(AirMass,predHbeta,yerr=errpredHbeta ,
                            fmt = 'o',
                            markersize = 3,
                            color = 'b',
                            zorder = 300,
                            antialiased = True,linewidth=2,label='libradtran')
plt.xlabel('airmass')
plt.ylabel('equivalent width in nm')
plt.ylim(0.,5.)
plt.title('equivalent width for atmospheric H beta absorption line (486 nm)')
plt.legend(loc='upper left')

# %% [markdown]
# # H2O equivalent line

# %%
PDF('Equivalent_Width_plot_H2O.pdf',size=(600,500))
# Out:
# \includegraphics[width=1.0\textwidth]{Equivalent_Width_plot_H2O.pdf}

# %% [markdown]
#     AirMass : [1.1070173712070741, 1.7710645458576959, 1.4353960968637178, 1.2256076238203211]
#     data H2O : [4.4994714344963542, 9.4510902450491709, 7.0858415893736773, 5.8568969036140466]
#     error data H2O : [0.055936006532355254, 0.11667863558783782, 0.074853761961620677, 0.067626872913491884]
#     pred H2O :  [8.3798719734527296, 10.610412567466719, 9.5794819793218657, 8.8394930307511359]
#     error pred H2O : [0.25549453655829146, 0.24479385320878211, 0.24882263604047539, 0.25275860927169591]

# %%
AirMass=np.array([ 1.7710645458576959, 1.4353960968637178, 1.2256076238203211,1.1070173712070741])
dataH2O=np.array([ 9.4510902450491709, 7.0858415893736773, 5.8568969036140466,4.4994714344963542])
errdataH2O=np.array([0.11667863558783782, 0.074853761961620677, 0.067626872913491884,0.055936006532355254 ])
predH2O=np.array([10.610412567466719, 9.5794819793218657, 8.8394930307511359,8.3798719734527296] )                
errpredH2O=np.array([0.24479385320878211, 0.24882263604047539, 0.25275860927169591,0.25549453655829146 ])

# %%
plt.figure(figsize=(10,6))
plt.plot(AirMass,dataH2O,'r--')
plt.errorbar(AirMass,dataH2O,yerr=errdataH2O ,
                                 fmt='s',
                                 markersize = 3,
                                 color = 'r',
                                zorder = 300,
                                antialiased = True,linewidth=2,label='data')
plt.plot(AirMass,predH2O,'b--')
plt.errorbar(AirMass,predH2O,yerr=errpredH2O ,
                            fmt = 'o',
                            markersize = 3,
                            color = 'b',
                            zorder = 300,
                            antialiased = True,linewidth=2,label='libradtran')
plt.xlabel('airmass')
plt.ylabel('equivalent width in nm')
plt.ylim(0.,12.)
plt.title('equivalent width for atmospheric $H_2O$ absorption line (960 nm)')
plt.legend(loc='best')

# %%
figname='AllEquivalentWidth.pdf'
f, (ax2, ax1, ax3) = plt.subplots(1,3, sharex=True, figsize=(21,5))
ax1.plot(AirMass,dataO2,'r--')
ax1.errorbar(AirMass,dataO2,yerr=errdataO2 ,
                                 fmt='s',
                                 markersize = 3,
                                 color = 'r',
                                zorder = 300,
                                antialiased = True,linewidth=2,label='data')
ax1.plot(AirMass,predO2,'b--')
ax1.errorbar(AirMass,predO2,yerr=errpredO2 ,
                            fmt = 'o',
                            markersize = 3,
                            color = 'b',
                            zorder = 300,
                            antialiased = True,linewidth=2,label='libradtran')
ax1.set_xlabel('airmass')
ax1.set_ylabel('equivalent width in nm')
ax1.set_ylim(0.,5.)
ax1.set_title('E.W. for atmospheric O$_2$ absorption line (759 nm)')
ax1.legend(loc='upper left')


ax2.plot(AirMass,dataHbeta,'r--')
ax2.errorbar(AirMass,dataHbeta,yerr=errdataHbeta ,
                                 fmt='s',
                                 markersize = 3,
                                 color = 'r',
                                zorder = 300,
                                antialiased = True,linewidth=2,label='data')
ax2.plot(AirMass,predHbeta,'b--')
ax2.errorbar(AirMass,predHbeta,yerr=errpredHbeta ,
                            fmt = 'o',
                            markersize = 3,
                            color = 'b',
                            zorder = 300,
                            antialiased = True,linewidth=2,label='libradtran')
ax2.set_xlabel('airmass')
ax2.set_ylabel('equivalent width in nm')
ax2.set_ylim(0.,5.)
ax2.set_title('E.W. star H beta absorption line (486 nm)')
ax2.legend(loc='upper left')


ax3.plot(AirMass,dataH2O,'r--')
ax3.errorbar(AirMass,dataH2O,yerr=errdataH2O ,
                                 fmt='s',
                                 markersize = 3,
                                 color = 'r',
                                zorder = 300,
                                antialiased = True,linewidth=2,label='data')
ax3.plot(AirMass,predH2O,'b--')
ax3.errorbar(AirMass,predH2O,yerr=errpredH2O ,
                            fmt = 'o',
                            markersize = 3,
                            color = 'b',
                            zorder = 300,
                            antialiased = True,linewidth=2,label='libradtran')
ax3.set_xlabel('airmass')
ax3.set_ylabel('equivalent width in nm')
ax3.set_ylim(0.,13.)
ax3.set_title('E.W.for atmospheric $H_2O$ absorption line (960 nm)')
ax3.legend(loc='upper left')

#plt.suptitle('Equivalent width of absorption lines or bands in data and in simulation')
plt.savefig(figname,bbox_inches='tight')

# %% [markdown]
# ## H alpha

# %%
PDF('Equivalent_Width_plot_Halpha.pdf',size=(600,500))
# Out:
# \includegraphics[width=1.0\textwidth]{Equivalent_Width_plot_Halpha.pdf}

# %%
AirMass=np.array([ 1.7710645458576959, 1.4353960968637178, 1.2256076238203211,1.1070173712070741])
dataHalpha=np.array([ 0.6749480604498852, 0.390899601476836, 0.60363615093213385,0.61615621481119376])
errdataHalpha=np.array([ 0.053620196997246787, 0.026383071109638785, 0.025014107923774981,0.014053702744373949])
predHalpha=np.array([ 1.4182575402756183, 1.4005161187062896, 1.3893395090901717,1.3829916411424028])
errpredHalpha=np.array([0.03178861927145827, 0.031010865924939648, 0.03052826240965224,0.030256863608604301])

# %%
plt.figure(figsize=(10,6))
plt.plot(AirMass,dataHalpha,'r--')
plt.errorbar(AirMass,dataHalpha,yerr=errdataHalpha ,
                                 fmt='s',
                                 markersize = 3,
                                 color = 'r',
                                zorder = 300,
                                antialiased = True,linewidth=2,label='data')
plt.plot(AirMass,predHalpha,'b--')
plt.errorbar(AirMass,predHalpha,yerr=errpredHalpha ,
                            fmt = 'o',
                            markersize = 3,
                            color = 'b',
                            zorder = 300,
                            antialiased = True,linewidth=2,label='libradtran')
plt.xlabel('airmass')
plt.ylabel('equivalent width in nm')
plt.ylim(0.,2.)
plt.title('equivalent width for atmospheric H-alpha absorption line')
plt.legend(loc='best')

# %%
figname='UpdateAllEquivalentWidth.pdf'
f, ((ax1, ax2), (ax3,ax4)) = plt.subplots(2,2, sharex=True, figsize=(21,12))
ax3.plot(AirMass,dataO2,'r--')
ax3.errorbar(AirMass,dataO2,yerr=errdataO2 ,
                                 fmt='s',
                                 markersize = 3,
                                 color = 'r',
                                zorder = 300,
                                antialiased = True,linewidth=2,label='data')
ax3.plot(AirMass,predO2,'b--')
ax3.errorbar(AirMass,predO2,yerr=errpredO2 ,
                            fmt = 'o',
                            markersize = 3,
                            color = 'b',
                            zorder = 300,
                            antialiased = True,linewidth=2,label='libradtran')
ax3.set_xlabel('airmass')
ax3.set_ylabel('equivalent width in nm')
ax3.set_ylim(0.,5.)
ax3.set_title('E.W. for atmospheric O$_2$ absorption line (759 nm)')
ax3.legend(loc='upper left')


ax1.plot(AirMass,dataHbeta,'r--')
ax1.errorbar(AirMass,dataHbeta,yerr=errdataHbeta ,
                                 fmt='s',
                                 markersize = 3,
                                 color = 'r',
                                zorder = 300,
                                antialiased = True,linewidth=2,label='data')
ax1.plot(AirMass,predHbeta,'b--')
ax1.errorbar(AirMass,predHbeta,yerr=errpredHbeta ,
                            fmt = 'o',
                            markersize = 3,
                            color = 'b',
                            zorder = 300,
                            antialiased = True,linewidth=2,label='libradtran')
ax1.set_xlabel('airmass')
ax1.set_ylabel('equivalent width in nm')
ax1.set_ylim(0.,5.)
ax1.set_title('E.W. star H-beta absorption line (486 nm)')
ax1.legend(loc='upper left')


ax4.plot(AirMass,dataH2O,'r--')
ax4.errorbar(AirMass,dataH2O,yerr=errdataH2O ,
                                 fmt='s',
                                 markersize = 3,
                                 color = 'r',
                                zorder = 300,
                                antialiased = True,linewidth=2,label='data')
ax4.plot(AirMass,predH2O,'b--')
ax4.errorbar(AirMass,predH2O,yerr=errpredH2O ,
                            fmt = 'o',
                            markersize = 3,
                            color = 'b',
                            zorder = 300,
                            antialiased = True,linewidth=2,label='libradtran')
ax4.set_xlabel('airmass')
ax4.set_ylabel('equivalent width in nm')
ax4.set_ylim(0.,13.)
ax4.set_title('E.W.for atmospheric $H_2O$ absorption line (960 nm)')
ax4.legend(loc='upper left')

#plt.suptitle('Equivalent width of absorption lines or bands in data and in simulation')
plt.savefig(figname,bbox_inches='tight')



ax2.plot(AirMass,dataHalpha,'r--')
ax2.errorbar(AirMass,dataHalpha,yerr=errdataHalpha ,
                                 fmt='s',
                                 markersize = 3,
                                 color = 'r',
                                zorder = 300,
                                antialiased = True,linewidth=2,label='data')
ax2.plot(AirMass,predHalpha,'b--')
ax2.errorbar(AirMass,predHalpha,yerr=errpredHalpha ,
                            fmt = 'o',
                            markersize = 3,
                            color = 'b',
                            zorder = 300,
                            antialiased = True,linewidth=2,label='libradtran')
ax2.set_xlabel('airmass')
ax2.set_ylabel('equivalent width in nm')
ax2.set_ylim(0.,5.)
ax2.set_title('equivalent width for atmospheric H-alpha absorption line (656 nm)')
ax2.legend(loc='best')

plt.suptitle('Preliminary Equivalent width of absorption lines or bands in data and in simulation',fontsize=25)
plt.savefig(figname,bbox_inches='tight')
