# %% [markdown]
# # Transparencies for Monocam
#
# - author Sylvie Dagoret-Campagne
# - creation date Sunday Jyly 3rd 2016

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
# %matplotlib inline

# %%
currentpath=os.getcwd()
outpath='./monocam_2016-05-11/afglus'
root_filename='UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_'
ext_filename='.out'
numstart=1
numstop=132

# %%
#currentpath=os.getcwd()
#outpath='./monocam_2016-05-09/afglus'
#root_filename='UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_'
#ext_filename='.out'
#numstart=1
#numstop=25

# %%
#currentpath=os.getcwd()
#outpath='./monocam_2016-05-10/afglus'
#root_filename='UVSPEC_REPTRAN_SOLAR_ALT22_COARSE_'
#ext_filename='.out'
#numstart=1
#numstop=13

# %%
filelist = []
NBFILES=numstop-numstart+1
for index in range(numstart,numstop+1):
    if index != 102:
        filename=root_filename+str(index)+ext_filename
        fullfilename=os.path.join(outpath,filename)
        filelist.append(fullfilename)

# %%
figname='SimulatedTransparenciesForMonocam.pdf'
fig1 = plt.figure(figsize=(20,15))
for index,file in enumerate(filelist):       
    array=np.loadtxt(file)
    x=array[:,0]
    y=array[:,1]
    plt.plot(x,y,'-')   
plt.xlim([0, 1000.])
plt.tick_params(axis='y', which='minor')
plt.grid(True,which='both')
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlabel('$\lambda$ (nm)',fontsize=20)
plt.ylabel('air transmission',fontsize=20)
plt.title('Atmospheric transmission at NOFS',fontsize=30)
plt.legend(loc='best')
plt.savefig(figname)
